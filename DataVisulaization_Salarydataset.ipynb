# %% [markdown]
# <a href="https://colab.research.google.com/github/Naveenrajkumar1389/Machine-learning/blob/main/DataVisulaization_Salarydataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

dataset = pd.read_csv("/content/Salaries.csv")

# %%
dataset.head()

# %%
rank=dataset['rank']
discipline=dataset['discipline']
phd=dataset['phd']
service=dataset['service']
sex=dataset['sex']
salary=dataset['salary']

# %%
dataset.plot()
# Out:
# <Axes: >

# %%
dataset[['rank','discipline','phd','service','salary']].plot()
# Out:
# <Axes: >

# %%
dataset[['phd','service']].plot()
# Out:
# <Axes: >

# %%
dataset1=dataset.groupby(["service"]).sum()
dataset1.sort_values("salary",ascending=False,inplace = True)
dataset1.head()
# Out:
# <ipython-input-16-215f0b03c67f>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dataset1=dataset.groupby(["service"]).sum()
#          phd  salary
# service
# 19       178  769448
# 3         56  635216
# 18        91  603060
# 0         26  519500
# 7         70  440408

# %%
dataset1['salary'].plot.bar()
# Out:
# <Axes: xlabel='service'>

# %%
dataset[['phd','service']].head(5).plot.bar(title="phd vs service\n 2018",color=['g','red'])
# Out:
# <Axes: title={'center': 'phd vs service\n 2018'}>

# %%
dataset['salary'].head(5).plot.pie(autopct='%.2f')
# Out:
# <Axes: ylabel='salary'>

# %%
dataset[['phd','salary']].head(100).plot.box()
# Out:
# <Axes: >

# %%
dataset['salary'].head(20).plot.hist()
# Out:
# <Axes: ylabel='Frequency'>
