# %% [markdown]
# <a href="https://colab.research.google.com/github/Naveenrajkumar1389/Machine-learning/blob/main/Data_Manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/company.csv")
df.head(10)
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0
# 5  Infosys   NaN  5000.0  Calcutta   India       0
# 6      TCS   NaN  6000.0   Chennai   India       1
# 7  Infosys  23.0  7000.0    Mumbai   India       1
# 8      TCS  34.0  8000.0  Calcutta   India       1
# 9      CTS  45.0  9000.0     Delhi   India       0

# %%
df.tail(10)
# Out:
#              Company   Age  Salary      Place Country  Gender
# 138              CTS  44.0  3033.0     Cochin   India       0
# 139       Congnizant  22.0  2934.0      Noida   India       0
# 140          Infosys  44.0  4034.0  Hyderabad   India       0
# 141              TCS  33.0  5034.0   Calcutta   India       0
# 142  Infosys Pvt Lmt  22.0  8202.0     Mumbai   India       0
# 143              TCS  33.0  9024.0   Calcutta   India       1
# 144          Infosys  22.0  8787.0   Calcutta   India       1
# 145          Infosys  44.0  4034.0      Delhi   India       1
# 146              TCS  33.0  5034.0     Mumbai   India       1
# 147          Infosys  22.0  8202.0     Cochin   India       0

# %%
df.shape
# Out:
# (148, 6)

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place', 'Country', 'Gender'], dtype='object')

# %%
df.head()
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0

# %%
df.shape[0]
# Out:
# 148

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  140 non-null    object
#  1   Age      130 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
#  4   Country  148 non-null    object
#  5   Gender   148 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.1+ KB

# %%
df.describe()
# Out:
#               Age       Salary      Gender
# count  130.000000   124.000000  148.000000
# mean    30.484615  5312.467742    0.222973
# std     11.096640  2573.764683    0.417654
# min      0.000000  1089.000000    0.000000
# 25%     22.000000  3030.000000    0.000000
# 50%     32.500000  5000.000000    0.000000
# 75%     37.750000  8000.000000    0.000000
# max     54.000000  9876.000000    1.000000

# %%
df.iloc[20:101,:2]
# Out:
#      Company   Age
# 20       TCS  37.0
# 21   Infosys  50.0
# 22       TCS  21.0
# 23   Infosys   NaN
# 24       TCS   NaN
# ..       ...   ...
# 96       TCS   NaN
# 97   Infosys  22.0
# 98       TCS  33.0
# 99       CTS  44.0
# 100      CTS  22.0
#
# [81 rows x 2 columns]

# %%
df.loc[20:100,["Company","Age"]]
# Out:
#      Company   Age
# 20       TCS  37.0
# 21   Infosys  50.0
# 22       TCS  21.0
# 23   Infosys   NaN
# 24       TCS   NaN
# ..       ...   ...
# 96       TCS   NaN
# 97   Infosys  22.0
# 98       TCS  33.0
# 99       CTS  44.0
# 100      CTS  22.0
#
# [81 rows x 2 columns]

# %%
df.loc[100,'Place']
# Out:
# 'Cochin'

# %%
df.loc[100,"Place"]="Noida"
df.loc[100,"Place"]
# Out:
# 'Noida'

# %%
df.loc[100,:]
# Out:
# Company      CTS
# Age         22.0
# Salary       NaN
# Place      Noida
# Country    India
# Gender         0
# Name: 100, dtype: object

# %%
#change column place to city
df.rename(columns={'Place':'City'},inplace=True)
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'City', 'Country', 'Gender'], dtype='object')

# %%
df.nunique()
# Out:
# Company     6
# Age        29
# Salary     40
# City       11
# Country     1
# Gender      2
# dtype: int64

# %%
df.Company.unique()
# Out:
# array(['TCS', 'Infosys', 'CTS', nan, 'Tata Consultancy Services',
#        'Congnizant', 'Infosys Pvt Lmt'], dtype=object)

# %%
df.Company.value_counts()
# Out:
# TCS                          53
# Infosys                      45
# CTS                          36
# Tata Consultancy Services     2
# Congnizant                    2
# Infosys Pvt Lmt               2
# Name: Company, dtype: int64

# %%
df.apply(lambda x:print(x.value_counts()))
# Out:
# TCS                          53
# Infosys                      45
# CTS                          36
# Tata Consultancy Services     2
# Congnizant                    2
# Infosys Pvt Lmt               2
# Name: Company, dtype: int64
# 22.0    16
# 33.0    13
# 44.0    10
# 23.0     8
# 34.0     8
# 21.0     8
# 32.0     7
# 35.0     6
# 0.0      6
# 41.0     5
# 45.0     4
# 43.0     4
# 24.0     4
# 20.0     3
# 31.0     3
# 25.0     3
# 36.0     3
# 40.0     3
# 26.0     2
# 30.0     2
# 46.0     2
# 50.0     2
# 37.0     2
# 19.0     1
# 38.0     1
# 51.0     1
# 18.0     1
# 17.0     1
# 54.0     1
# Name: Age, dtype: int64
# 3000.0    9
# 5000.0    6
# 8202.0    5
# 5034.0    5
# 4034.0    5
# 2300.0    4
# 5835.0    4
# 8787.0    4
# 9024.0    4
# 2934.0    4
# 9284.0    4
# 8345.0    4
# 8943.0    4
# 7084.0    4
# 2034.0    4
# 4824.0    4
# 3045.0    4
# 3184.0    4
# 1234.0    4
# 1089.0    4
# 9000.0    3
# 6000.0    3
# 7000.0    3
# 8000.0    3
# 3030.0    3
# ...

# %%
df.Company.replace({'Tata'})
# Out:
# 0                  TCS
# 1              Infosys
# 2                  TCS
# 3              Infosys
# 4                  TCS
#             ...
# 142    Infosys Pvt Lmt
# 143                TCS
# 145            Infosys
# 146                TCS
# 147            Infosys
# Name: Company, Length: 139, dtype: object

# %%
import numpy as np
df[df.Age==0] = np.nan

# %%
df.Age.isna().sum()
# Out:
# 18

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
del df["Country"]
df
# Out:
#              Company   Age  Salary      City  Gender
# 0                TCS  20.0     NaN   Chennai     0.0
# 1            Infosys  30.0     NaN    Mumbai     0.0
# 2                TCS  35.0  2300.0  Calcutta     0.0
# 3            Infosys  40.0  3000.0     Delhi     0.0
# 4                TCS  23.0  4000.0    Mumbai     0.0
# ..               ...   ...     ...       ...     ...
# 142  Infosys Pvt Lmt  22.0  8202.0    Mumbai     0.0
# 143              TCS  33.0  9024.0  Calcutta     1.0
# 145          Infosys  44.0  4034.0     Delhi     1.0
# 146              TCS  33.0  5034.0    Mumbai     1.0
# 147          Infosys  22.0  8202.0    Cochin     0.0
#
# [139 rows x 5 columns]

# %%
df.shape
# Out:
# (139, 5)

# %%
df.Company.value_counts()
# Out:
# TCS                          50
# Infosys                      41
# CTS                          33
# Tata Consultancy Services     2
# Congnizant                    2
# Infosys Pvt Lmt               2
# Name: Company, dtype: int64

# %%
df.City.value_counts()
# Out:
# Mumbai        33
# Calcutta      30
# Chennai       13
# Delhi         13
# Cochin        12
# Noida          9
# Hyderabad      8
# Podicherry     2
# Pune           2
# Bhopal         1
# Nagpur         1
# Name: City, dtype: int64

# %%
df.isna().sum()
# Out:
# Company     9
# Age        18
# Salary     24
# City       15
# Gender      1
# dtype: int64

# %%
df.dropna(subset=["Salary"],inplace=True)

# %%
df.Company.fillna(df.Company.mode,inplace=True)

# %%
df['Age']=pd.to_numeric(df['Age'],errors='coerce')
df['Salary']=pd.to_numeric(df['Salary'],errors='coerce')

# %%
df.Age.fillna(df.Age.mean(),inplace=True)
df.Salary.fillna(df.Salary.median(),inplace=True)

# %%
df1= df[(df.Age >40) & (df.Salary < 5000)]
df1
# Out:
#      Company   Age  Salary       City  Gender
# 21   Infosys  50.0  3184.0      Delhi     0.0
# 32   Infosys  45.0  4034.0   Calcutta     0.0
# 39   Infosys  41.0  3000.0     Mumbai     0.0
# 50   Infosys  41.0  3000.0    Chennai     0.0
# 57   Infosys  51.0  3184.0  Hyderabad     0.0
# 68   Infosys  43.0  4034.0     Mumbai     0.0
# 75   Infosys  44.0  3000.0     Cochin     0.0
# 86   Infosys  41.0  3000.0      Delhi     0.0
# 93   Infosys  54.0  3184.0     Mumbai     0.0
# 104  Infosys  44.0  4034.0      Delhi     0.0
# 122  Infosys  44.0  3234.0     Mumbai     0.0
# 129  Infosys  50.0  3184.0   Calcutta     0.0
# 138      CTS  44.0  3033.0     Cochin     0.0
# 140  Infosys  44.0  4034.0  Hyderabad     0.0
# 145  Infosys  44.0  4034.0      Delhi     1.0

# %%
# %matplotlib inline
df.Age.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'City', 'Gender'], dtype='object')

# %%
df.groupby('City').Salary.agg(["mean","median","count"])
# Out:
#                    mean  median  count
# City
# Bhopal      7000.000000  7000.0      1
# Calcutta    5115.400000  4824.0     25
# Chennai     5824.200000  5917.5     10
# Cochin      5053.000000  5017.0     12
# Delhi       4925.545455  4034.0     11
# Hyderabad   4382.833333  3609.0      6
# Mumbai      4895.269231  4429.0     26
# Nagpur      8000.000000  8000.0      1
# Noida       4387.000000  4000.0      7
# Podicherry  6157.000000  6157.0      2
# Pune        9000.000000  9000.0      1

# %%
df.groupby("Company").Age.mean()
# Out:
# Company
# <bound method Series.mode of 2                  TCS\n3              Infosys\n4                  TCS\n5              Infosys\n6                  TCS\n            ...       \n142    Infosys Pvt Lmt\n143                TCS\n145            Infosys\n146                TCS\n147            Infosys\nName: Company, Length: 115, dtype: object>    25.658586
# CTS                                                                                                                                                                                                                                                                                                                                                34.173913
# ...

# %%
import pandas as pd

excel_file_opath
