# %% [markdown]
# <a href="https://colab.research.google.com/github/Naveenrajkumar1389/Machine-learning/blob/main/DataPreprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/company.csv")

# %%
df.shape
# Out:
# (148, 6)

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place', 'Country', 'Gender'], dtype='object')

# %%
df.head()
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0

# %%
df.tail(15)
# Out:
#                        Company   Age  Salary      Place Country  Gender
# 133                        NaN  22.0  8943.0    Chennai   India       0
# 134  Tata Consultancy Services  31.0  8345.0     Mumbai   India       0
# 135                        CTS  40.0  9284.0   Calcutta   India       1
# 136                        NaN   NaN     NaN      Delhi   India       0
# 137                        CTS  31.0  2034.0     Mumbai   India       0
# 138                        CTS  44.0  3033.0     Cochin   India       0
# 139                 Congnizant  22.0  2934.0      Noida   India       0
# 140                    Infosys  44.0  4034.0  Hyderabad   India       0
# 141                        TCS  33.0  5034.0   Calcutta   India       0
# 142            Infosys Pvt Lmt  22.0  8202.0     Mumbai   India       0
# 143                        TCS  33.0  9024.0   Calcutta   India       1
# 144                    Infosys  22.0  8787.0   Calcutta   India       1
# ...

# %%
df.shape[0]
# Out:
# 148

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  140 non-null    object
#  1   Age      130 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
#  4   Country  148 non-null    object
#  5   Gender   148 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.1+ KB

# %%
# Check the basic Statistics of Dataframe. Give your inference from the stats
# df.describe().T, generates summary statistics for the numerical columns in the DataFrame df and then transposing the result to have these statistics
# presented as columns with the original column names as the row index.

df.describe().T
# Out:
#         count         mean          std     min     25%     50%      75%  \
# Age     130.0    30.484615    11.096640     0.0    22.0    32.5    37.75
# Salary  124.0  5312.467742  2573.764683  1089.0  3030.0  5000.0  8000.00
# Gender  148.0     0.222973     0.417654     0.0     0.0     0.0     0.00
#
#            max
# Age       54.0
# Salary  9876.0
# Gender     1.0

# %%
# Retrieve 20 to 100 rows and Company and age usig iloc
# iloc - integer-location based indexing
# 20:101: This selects rows from index 20 (inclusive) up to index 101 (exclusive). In other words, it selects rows 20 through 100.
# :2: This selects columns from the beginning (index 0) up to, but not including, the third column (index 2). So, it selects the first and second columns.
# df.iloc[20:101, :2] - Selects a subset of rows from index 20 to 100 and the first two columns of the DataFrame df.

df.iloc[20:101,:2]
# Out:
#      Company   Age
# 20       TCS  37.0
# 21   Infosys  50.0
# 22       TCS  21.0
# 23   Infosys   NaN
# 24       TCS   NaN
# ..       ...   ...
# 96       TCS   NaN
# 97   Infosys  22.0
# 98       TCS  33.0
# 99       CTS  44.0
# 100      CTS  22.0
#
# [81 rows x 2 columns]

# %%
# Retrieve 20 to 100 rows and Company and age usig loc

df.loc[20:100,["Company","Age"]]
# Out:
#      Company   Age
# 20       TCS  37.0
# 21   Infosys  50.0
# 22       TCS  21.0
# 23   Infosys   NaN
# 24       TCS   NaN
# ..       ...   ...
# 96       TCS   NaN
# 97   Infosys  22.0
# 98       TCS  33.0
# 99       CTS  44.0
# 100      CTS  22.0
#
# [81 rows x 2 columns]

# %%
# To check what is the place at 100th row before changing the place value

df.loc[100,"Place"]
# Out:
# 'Cochin'

# %%
# Chage the data in 100th row and Place as 'Noida'

df.loc[100,"Place"] = "Noida"
df.loc[100,"Place"]
# Out:
# 'Noida'

# %%
# Retrieve the record at row id 100

df.loc[100,:]
# Out:
# Company      CTS
# Age         22.0
# Salary       NaN
# Place      Noida
# Country    India
# Gender         0
# Name: 100, dtype: object

# %%
# Change the column 'Place' to 'City'

df.rename(columns={'Place': 'City'}, inplace=True)
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'City', 'Country', 'Gender'], dtype='object')

# %%
# List down the unique data in each columns and find length of unique data

df.nunique()
# Out:
# Company     6
# Age        29
# Salary     40
# City       11
# Country     1
# Gender      2
# dtype: int64

# %%
# Unique values of a particular column

df.Company.unique()
# Out:
# array(['TCS', 'Infosys', 'CTS', nan, 'Tata Consultancy Services',
#        'Congnizant', 'Infosys Pvt Lmt'], dtype=object)

# %%
df.Company.value_counts()
# Out:
# TCS                          53
# Infosys                      45
# CTS                          36
# Tata Consultancy Services     2
# Congnizant                    2
# Infosys Pvt Lmt               2
# Name: Company, dtype: int64

# %%
df.apply(lambda x:print(x.value_counts()))
# Out:
# TCS                          53
# Infosys                      45
# CTS                          36
# Tata Consultancy Services     2
# Congnizant                    2
# Infosys Pvt Lmt               2
# Name: Company, dtype: int64
# 22.0    16
# 33.0    13
# 44.0    10
# 23.0     8
# 34.0     8
# 21.0     8
# 32.0     7
# 35.0     6
# 0.0      6
# 41.0     5
# 45.0     4
# 43.0     4
# 24.0     4
# 20.0     3
# 31.0     3
# 25.0     3
# 36.0     3
# 40.0     3
# 26.0     2
# 30.0     2
# 46.0     2
# 50.0     2
# 37.0     2
# 19.0     1
# 38.0     1
# 51.0     1
# 18.0     1
# 17.0     1
# 54.0     1
# Name: Age, dtype: int64
# 3000.0    9
# 5000.0    6
# 8202.0    5
# 5034.0    5
# 4034.0    5
# 2300.0    4
# 5835.0    4
# 8787.0    4
# 9024.0    4
# 2934.0    4
# 9284.0    4
# 8345.0    4
# 8943.0    4
# 7084.0    4
# 2034.0    4
# 4824.0    4
# 3045.0    4
# 3184.0    4
# 1234.0    4
# 1089.0    4
# 9000.0    3
# 6000.0    3
# 7000.0    3
# 8000.0    3
# 3030.0    3
# ...

# %%
# Rename all the possible labels of column in Company as three labels as TCS, CTS & Infosys

df.Company.replace({"Tata Consultancy Services":"TCS", "Congnizant":"CTS","Infosys Pvt Lmt":"Infosys"}, inplace=True)

# %%
df.Company.value_counts()
# Out:
# TCS        55
# Infosys    47
# CTS        38
# Name: Company, dtype: int64

# %%
#  Any rows in the DataFrame where the "Age" column had a value of 0 will have their "Age" values replaced with NaN (missing value).
import numpy as np

df[df.Age==0] = np.nan

# %%
# count of missing values in the "Age" column
df.Age.isna().sum()
# Out:
# 24

# %%
# Check how many duplicated data is there?

df.duplicated().sum()
# Out:
# 9

# %%
# Remove all duplicated row's data

df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Remove the column 'Country'

#df1 = df.drop(columns="Country")

del df["Country"]
df
# Out:
#      Company   Age  Salary      City  Gender
# 0        TCS  20.0     NaN   Chennai     0.0
# 1    Infosys  30.0     NaN    Mumbai     0.0
# 2        TCS  35.0  2300.0  Calcutta     0.0
# 3    Infosys  40.0  3000.0     Delhi     0.0
# 4        TCS  23.0  4000.0    Mumbai     0.0
# ..       ...   ...     ...       ...     ...
# 142  Infosys  22.0  8202.0    Mumbai     0.0
# 143      TCS  33.0  9024.0  Calcutta     1.0
# 145  Infosys  44.0  4034.0     Delhi     1.0
# 146      TCS  33.0  5034.0    Mumbai     1.0
# 147  Infosys  22.0  8202.0    Cochin     0.0
#
# [139 rows x 5 columns]

# %%
# Remove the row number 137

df.drop(index=136)
# Out:
#      Company   Age  Salary      City  Gender
# 0        TCS  20.0     NaN   Chennai     0.0
# 1    Infosys  30.0     NaN    Mumbai     0.0
# 2        TCS  35.0  2300.0  Calcutta     0.0
# 3    Infosys  40.0  3000.0     Delhi     0.0
# 4        TCS  23.0  4000.0    Mumbai     0.0
# ..       ...   ...     ...       ...     ...
# 142  Infosys  22.0  8202.0    Mumbai     0.0
# 143      TCS  33.0  9024.0  Calcutta     1.0
# 145  Infosys  44.0  4034.0     Delhi     1.0
# 146      TCS  33.0  5034.0    Mumbai     1.0
# 147  Infosys  22.0  8202.0    Cochin     0.0
#
# [138 rows x 5 columns]

# %%
# Find number of each labels in Company

df.Company.value_counts()
# Out:
# TCS        52
# Infosys    43
# CTS        35
# Name: Company, dtype: int64

# %%
df.City.value_counts()
# Out:
# Mumbai        33
# Calcutta      30
# Chennai       13
# Delhi         13
# Cochin        12
# Noida          9
# Hyderabad      8
# Podicherry     2
# Pune           2
# Bhopal         1
# Nagpur         1
# Name: City, dtype: int64

# %%
# find out the missing values column-wise
df.isna().sum()
# Out:
# Company     9
# Age        18
# Salary     24
# City       15
# Gender      1
# dtype: int64

# %%
# Remove all Null values in Salary

df.dropna(subset=["Salary"], inplace=True)

# %%
# Replace the Null values in Comapany with mode

df.Company.fillna(df.Company.mode(), inplace=True)

# %%
#df.Age.astype("float")
#df.loc[df['Age'].notnull(), 'Age'].apply(int)
#pd.to_numeric(df["Age"])

df["Age"] = pd.to_numeric(df["Age"], errors='coerce')
df["Salary"] = pd.to_numeric(df["Salary"], errors='coerce')

# %%
# Replace the null value in age with mean

df.Age.fillna(df.Age.mean(), inplace=True)
df.Salary.fillna(df.Salary.median(), inplace=True)

# %%
# Filter the data with age>40 and Salary<5000

df[(df.Age>40) & (df.Salary<5000)]

# print("No. of records : ", len(df[(df.Age>40) & (df.Salary<5000)]))
# Out:
#      Company   Age  Salary       City  Gender
# 21   Infosys  50.0  3184.0      Delhi     0.0
# 32   Infosys  45.0  4034.0   Calcutta     0.0
# 39   Infosys  41.0  3000.0     Mumbai     0.0
# 50   Infosys  41.0  3000.0    Chennai     0.0
# 57   Infosys  51.0  3184.0  Hyderabad     0.0
# 68   Infosys  43.0  4034.0     Mumbai     0.0
# 75   Infosys  44.0  3000.0     Cochin     0.0
# 86   Infosys  41.0  3000.0      Delhi     0.0
# 93   Infosys  54.0  3184.0     Mumbai     0.0
# 104  Infosys  44.0  4034.0      Delhi     0.0
# 122  Infosys  44.0  3234.0     Mumbai     0.0
# 129  Infosys  50.0  3184.0   Calcutta     0.0
# 138      CTS  44.0  3033.0     Cochin     0.0
# 140  Infosys  44.0  4034.0  Hyderabad     0.0
# 145  Infosys  44.0  4034.0      Delhi     1.0

# %%
# Draw an histogram chart for age, Salary

# %matplotlib inline

df.Age.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
# %matplotlib inline
df.Salary.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Draw the pie chart for city and Company

df.City.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='City'>

# %%
df.Company.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='Company'>

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'City', 'Gender'], dtype='object')

# %%
# Find the mean, count, median of salary with repective to the place/city

df.groupby("City").Salary.agg(["mean","median","count"])
# Out:
#                    mean  median  count
# City
# Bhopal      7000.000000  7000.0      1
# Calcutta    5115.400000  4824.0     25
# Chennai     5824.200000  5917.5     10
# Cochin      5053.000000  5017.0     12
# Delhi       4925.545455  4034.0     11
# Hyderabad   4382.833333  3609.0      6
# Mumbai      4895.269231  4429.0     26
# Nagpur      8000.000000  8000.0      1
# Noida       4387.000000  4000.0      7
# Podicherry  6157.000000  6157.0      2
# Pune        9000.000000  9000.0      1

# %%
# Find the mean age with repective to the Company

df.groupby("Company").Age.mean()
# Out:
# Company
# CTS        33.160000
# Infosys    33.950013
# TCS        31.137901
# Name: Age, dtype: float64

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#    Company        Age  Salary      City  Gender
# 2      TCS  35.000000  2300.0  Calcutta     0.0
# 3  Infosys  40.000000  3000.0     Delhi     0.0
# 4      TCS  23.000000  4000.0    Mumbai     0.0
# 5  Infosys  32.292929  5000.0  Calcutta     0.0
# 6      TCS  32.292929  6000.0   Chennai     1.0

# %%
df.isna().sum()
# Out:
# Company    0
# Age        0
# Salary     0
# City       0
# Gender     0
# dtype: int64

# %%
# List of column names from df that contain numeric data

num_col = df.select_dtypes(include=np.number).columns
num_col
# Out:
# Index(['Age', 'Salary', 'Gender'], dtype='object')

# %%
 # List of column names from df that contain categorical (non-numeric) data

cat_col = df.select_dtypes(exclude=np.number).columns
cat_col
# Out:
# Index(['Company', 'City'], dtype='object')

# %%
df[cat_col]
# Out:
#      Company      City
# 2        TCS  Calcutta
# 3    Infosys     Delhi
# 4        TCS    Mumbai
# 5    Infosys  Calcutta
# 6        TCS   Chennai
# ..       ...       ...
# 142  Infosys    Mumbai
# 143      TCS  Calcutta
# 145  Infosys     Delhi
# 146      TCS    Mumbai
# 147  Infosys    Cochin
#
# [98 rows x 2 columns]

# %%
#One hot encoding
encoded_cat_col = pd.get_dummies(df[cat_col])

# %%
encoded_cat_col
# Out:
#      Company_CTS  Company_Infosys  Company_TCS  City_Bhopal  City_Calcutta  \
# 2              0                0            1            0              1
# 3              0                1            0            0              0
# 4              0                0            1            0              0
# 5              0                1            0            0              1
# 6              0                0            1            0              0
# ..           ...              ...          ...          ...            ...
# 142            0                1            0            0              0
# 143            0                0            1            0              1
# 145            0                1            0            0              0
# 146            0                0            1            0              0
# 147            0                1            0            0              0
#
# ...

# %%
df_ready_model = pd.concat([df[num_col],encoded_cat_col], axis = 1)

# %%
df_ready_model
# Out:
#            Age  Salary  Gender  Company_CTS  Company_Infosys  Company_TCS  \
# 2    35.000000  2300.0     0.0            0                0            1
# 3    40.000000  3000.0     0.0            0                1            0
# 4    23.000000  4000.0     0.0            0                0            1
# 5    32.292929  5000.0     0.0            0                1            0
# 6    32.292929  6000.0     1.0            0                0            1
# ..         ...     ...     ...          ...              ...          ...
# 142  22.000000  8202.0     0.0            0                1            0
# 143  33.000000  9024.0     1.0            0                0            1
# 145  44.000000  4034.0     1.0            0                1            0
# 146  33.000000  5034.0     1.0            0                0            1
# 147  22.000000  8202.0     0.0            0                1            0
#
#      City_Bhopal  City_Calcutta  City_Chennai  City_Cochin  City_Delhi  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
for i in cat_col:
    df[i] = label_encoder.fit_transform(df[i])

# %%
df.City.value_counts()
# Out:
# 6     25
# 1     24
# 3     12
# 4     11
# 2      9
# 8      6
# 5      6
# 9      2
# 0      1
# 7      1
# 10     1
# Name: City, dtype: int64

# %%
#Performng standard scaling
from sklearn.preprocessing import StandardScaler

std_scale = StandardScaler().fit(df)
df_std = std_scale.transform(df)

# %%
df_std
# Out:
# array([[ 1.07486114e+00,  2.80627931e-01, -1.11106463e+00,
#         -1.20745013e+00, -5.53774924e-01],
#        [-2.09729002e-01,  8.57925796e-01, -8.33096884e-01,
#          2.94500032e-02, -5.53774924e-01],
#        [ 1.07486114e+00, -1.10488694e+00, -4.36000106e-01,
#          8.54050093e-01, -5.53774924e-01],
#        [-2.09729002e-01, -3.19292965e-02, -3.89033282e-02,
#         -1.20745013e+00, -5.53774924e-01],
#        [ 1.07486114e+00, -3.19292965e-02,  3.58193450e-01,
#         -7.95150086e-01,  1.80578780e+00],
#        [-2.09729002e-01, -1.10488694e+00,  7.55290228e-01,
#          8.54050093e-01,  1.80578780e+00],
#        [ 1.07486114e+00,  1.65168358e-01,  1.15238701e+00,
#         -1.20745013e+00,  1.80578780e+00],
#        [-1.49431914e+00,  1.43522366e+00,  1.54948378e+00,
#          2.94500032e-02, -5.53774924e-01],
#        [-1.49431914e+00,  1.65168358e-01, -1.59194883e+00,
#         -1.20745013e+00, -5.53774924e-01],
# ...

# %%
#Performng standard scaling
from sklearn.preprocessing import MinMaxScaler

minmax_scale = MinMaxScaler().fit_transform(df)

# %%
type(minmax_scale)
# Out:
# numpy.ndarray

# %%
pd.DataFrame(minmax_scale)
# Out:
#       0         1         2    3    4
# 0   1.0  0.486486  0.137817  0.1  0.0
# 1   0.5  0.621622  0.217480  0.4  0.0
# 2   1.0  0.162162  0.331285  0.6  0.0
# 3   0.5  0.413322  0.445089  0.1  0.0
# 4   1.0  0.413322  0.558894  0.2  1.0
# ..  ...       ...       ...  ...  ...
# 93  0.5  0.135135  0.809491  0.6  0.0
# 94  1.0  0.432432  0.903039  0.1  1.0
# 95  0.5  0.729730  0.335154  0.4  1.0
# 96  1.0  0.432432  0.448959  0.6  1.0
# 97  0.5  0.135135  0.809491  0.3  0.0
#
# [98 rows x 5 columns]

# %%
col = ["Company","City"]
onehot = pd.get_dummies(df[col])

# %%
col=["Age","Salary","Gender"]
dataf = pd.concat([df[col],onehot],axis=1)

# %%
dataf
# Out:
#            Age  Salary  Gender  Company  City
# 2    35.000000  2300.0     0.0        2     1
# 3    40.000000  3000.0     0.0        1     4
# 4    23.000000  4000.0     0.0        2     6
# 5    32.292929  5000.0     0.0        1     1
# 6    32.292929  6000.0     1.0        2     2
# ..         ...     ...     ...      ...   ...
# 142  22.000000  8202.0     0.0        1     6
# 143  33.000000  9024.0     1.0        2     1
# 145  44.000000  4034.0     1.0        1     4
# 146  33.000000  5034.0     1.0        2     6
# 147  22.000000  8202.0     0.0        1     3
#
# [98 rows x 5 columns]

# %%
import pandas as pd

excel_file_path="cleaned_data.xlsx"

dataf.to_excel(excel_file_path, index= False)

print("Dataframe has been saved to", excel_file_path)
# Out:
# Dataframe has been saved to cleaned_data.xlsx
